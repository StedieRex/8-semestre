# %% [markdown]
# # Espacios de color

# %% [markdown]
# * En caso de ser necesario se debe de instalar OpenCV sobre Jupyter Notebook

# %%
#pip install opencv-python

# %%
import cv2

# %% [markdown]
# Se carga una imagen de archivo

# %%
img = cv2.imread('input.jpg')

# %% [markdown]
# Una vez cargada la imagen en la variable "img", se obtiene la dimensión de la misma

# %%
dimensions = img.shape
print(dimensions)
# Out:
# (720, 1280, 3)

# %%
h = dimensions[0]
w = dimensions[1]

# %% [markdown]
# # Visualizando la Imagen de entrada

# %% [markdown]
# Se muestra de forma de cargar la imagen usando OpenCV como con MatPlotLib:

# %%
cv2.startWindowThread()
# Show original
cv2.imshow("original image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Para visualizar la imagen ahora con MatPlotLib:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Espacio de color RGB

# %% [markdown]
# El espacio de color RGB es el espacio

# %%
(b, g, r) = cv2.split(img)

# %% [markdown]
# Se muestran cada uno de los canales con MatPloit

# %%
plt.figure(figsize=(15,19))
plt.subplot(131)
plt.imshow(r, cmap='gray')
plt.title('R Channel')
plt.subplot(132)
plt.imshow(g, cmap='gray')
plt.title('G Channel')
plt.subplot(133)
plt.imshow(b, cmap='gray')
plt.title('B Channel')
plt.show()

# %% [markdown]
# Mostrando las imagenes polarizadas (Nota: solo polarizado no para renderizar)

# %%
import numpy as np

# %%
zeros = np.zeros(img.shape[:2], dtype = "uint8")

# %%
img_r = cv2.merge([r, zeros, zeros])
img_g = cv2.merge([zeros, g, zeros])
img_b = cv2.merge([zeros, zeros, b])

plt.figure(figsize=(15,10))
plt.subplot(131)
plt.imshow(img_r, cmap='gray')
plt.title('R Channel')

plt.figure(figsize=(15,10))
plt.subplot(132)
plt.imshow(img_g, cmap='gray')
plt.title('G Channel')

plt.figure(figsize=(15,10))
plt.subplot(133)
plt.imshow(img_b, cmap='gray')
plt.title('B Channel')

plt.show()

# %% [markdown]
# # Transformación a Escala de Grises

# %% [markdown]
# El siguiente ejemplo es para transformar una RGB a escalada

# %%
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Se va a transformar la imagen RGB a una escala de grises ponderada

# %%
w_r = 0.299
w_g = 0.587
w_b = 0.114

# %%
gray_lum = w_r * r +w_g * g + w_b * b

# %%
plt.imshow(gray_lum, cmap='gray')

# %%
plt.figure(figsize=(15,10))
plt.subplot(121)
plt.imshow(img_gray, cmap='gray')
plt.title('Imagen Esc. Grises Promedio')

plt.figure(figsize=(15,10))
plt.subplot(122)
plt.imshow(gray_lum, cmap='gray')
plt.title('Imagen Esc. Grises Ponderado')

plt.show()

# %% [markdown]
# nota: los valores genrados al tranformar RGB a HSV son automaticamente Tranformados por OpencCV a valores en el rango [0,255] a traves de las sguientes ecuaciones:
# 1. canal h:h<-H/2
# 2. canal s:s<-S*255
# 3. canal v:p<-V*255

# %% [markdown]
# las regiones obscuras son las que menos color de esa capa tiene
